# %%
from collections import defaultdict
import re
import requests

import bs4
from selenium import webdriver
import time
import tqdm

# %%
def url_from_page(page):
    return f'https://wikipedia.org/wiki/{page}'

def get_links_above_fold(page):
    resp = requests.get(url_from_page(page))
    soup = bs4.BeautifulSoup(resp.content)
    links = set()
    actual_stuff = soup.select('.mw-parser-output')
    if not actual_stuff:
        print(f'couldn\'t find anything for {page=}')
        return []
    for child in actual_stuff[0].children:
        # annoying 
        # see: https://stackoverflow.com/a/39689765
        if isinstance(child, bs4.NavigableString):
            continue
        
        if child.name == 'p':
            for a in child.findAll('a'):
                href = a.attrs.get('href')
                if href and href.startswith('/wiki/'):
                    link = href.lstrip('/wiki/')
                    if link.startswith('Help:') or link.startswith('File:'):
                        continue
                    links.add(link)
                    
        # not consistent, annoyingly
        elif child.name == 'div' and child.attrs.get('id') == 'toc' or child.attrs.get('class', [''])[0].startswith('toc'):
            break
    return list(links)

# %%
def build_graph(starting_point, max_visits=1000):
    to_visit = [starting_point]
    graph = {}
    num_visits = 0
    
    while to_visit and num_visits < max_visits:
        page = to_visit.pop(0)
        if page in graph:
            # this is a little redundant with our new_links stuff below,
            # but that doesn't catch things that get added to to_visit multiple times 
            # before they get visited.
            continue
        time.sleep(.01)
        try:
            graph[page] = get_links_above_fold(page)
        except Exception as e:
            print(e)
            continue
            
        new_links = [l for l in graph[page] if l not in graph]
        to_visit += new_links
        num_visits += 1
        
        if num_visits % 100 == 0:
            print(f'{num_visits=}; {len(to_visit)=}')
    return graph

# %%
douglas_loop = build_graph('I_Am_a_Strange_Loop', max_visits=100000)
# Out:
# num_visits=100; len(to_visit)=2077
# num_visits=200; len(to_visit)=3678
# num_visits=300; len(to_visit)=5699
# num_visits=400; len(to_visit)=7516
# num_visits=500; len(to_visit)=9612
# num_visits=600; len(to_visit)=11588
# num_visits=700; len(to_visit)=13391
# num_visits=800; len(to_visit)=15130
# num_visits=900; len(to_visit)=16516
# num_visits=1000; len(to_visit)=18210
# num_visits=1100; len(to_visit)=20111
# num_visits=1200; len(to_visit)=21488
# num_visits=1300; len(to_visit)=22645
# num_visits=1400; len(to_visit)=24045
# num_visits=1500; len(to_visit)=26101
# num_visits=1600; len(to_visit)=27830
# num_visits=1700; len(to_visit)=29762
# num_visits=1800; len(to_visit)=31153
# num_visits=1900; len(to_visit)=32574
# num_visits=2000; len(to_visit)=34084
# num_visits=2100; len(to_visit)=35395
# num_visits=2200; len(to_visit)=36632
# num_visits=2300; len(to_visit)=37926
# num_visits=2400; len(to_visit)=38835
# num_visits=2500; len(to_visit)=40014
# num_visits=2600; len(to_visit)=41152
# num_visits=2700; len(to_visit)=42591
# num_visits=2800; len(to_visit)=43724
# num_visits=2900; len(to_visit)=44778
# num_visits=3000; len(to_visit)=46218
# num_visits=3100; len(to_visit)=47222
# num_visits=3200; len(to_visit)=48241
# num_visits=3300; len(to_visit)=49727
# num_visits=3400; len(to_visit)=51008
# num_visits=3500; len(to_visit)=52236
# num_visits=3600; len(to_visit)=53428
# num_visits=3700; len(to_visit)=54821
# num_visits=3800; len(to_visit)=56120
# num_visits=3900; len(to_visit)=57481
# num_visits=4000; len(to_visit)=58604
# num_visits=4100; len(to_visit)=60653
# num_visits=4200; len(to_visit)=62515
# num_visits=4300; len(to_visit)=63856
# num_visits=4400; len(to_visit)=65316
# num_visits=4500; len(to_visit)=66992
# num_visits=4600; len(to_visit)=68545
# num_visits=4700; len(to_visit)=70078
# num_visits=4800; len(to_visit)=71778
# num_visits=4900; len(to_visit)=74040
# num_visits=5000; len(to_visit)=75585
# num_visits=5100; len(to_visit)=76825
# num_visits=5200; len(to_visit)=78333
# num_visits=5300; len(to_visit)=80233
# num_visits=5400; len(to_visit)=81592
# num_visits=5500; len(to_visit)=83453
# num_visits=5600; len(to_visit)=85532
# num_visits=5700; len(to_visit)=86740
# num_visits=5800; len(to_visit)=87754
# num_visits=5900; len(to_visit)=88749
# num_visits=6000; len(to_visit)=89967
# num_visits=6100; len(to_visit)=91034
# num_visits=6200; len(to_visit)=92018
# num_visits=6300; len(to_visit)=92865
# num_visits=6400; len(to_visit)=93960
# num_visits=6500; len(to_visit)=94940
# num_visits=6600; len(to_visit)=95756
# num_visits=6700; len(to_visit)=97275
# num_visits=6800; len(to_visit)=99490
# num_visits=6900; len(to_visit)=101366
# num_visits=7000; len(to_visit)=103243
# num_visits=7100; len(to_visit)=104478
# num_visits=7200; len(to_visit)=106071
# num_visits=7300; len(to_visit)=107483
# num_visits=7400; len(to_visit)=109177
# num_visits=7500; len(to_visit)=110348
# num_visits=7600; len(to_visit)=112254
# num_visits=7700; len(to_visit)=114161
# num_visits=7800; len(to_visit)=115468
# num_visits=7900; len(to_visit)=116864
# num_visits=8000; len(to_visit)=118746
# num_visits=8100; len(to_visit)=120406
# num_visits=8200; len(to_visit)=121404
# num_visits=8300; len(to_visit)=122935
# num_visits=8400; len(to_visit)=124538
# couldn't find anything for page='Answering_the_Question:_What_Is_Enlightenment%3F'
# num_visits=8500; len(to_visit)=126031
# num_visits=8600; len(to_visit)=127528
# num_visits=8700; len(to_visit)=129335
# num_visits=8800; len(to_visit)=130886
# num_visits=8900; len(to_visit)=131914
# num_visits=9000; len(to_visit)=133176
# num_visits=9100; len(to_visit)=134728
# num_visits=9200; len(to_visit)=136535
# num_visits=9300; len(to_visit)=137859
# num_visits=9400; len(to_visit)=138947
# num_visits=9500; len(to_visit)=140290
# num_visits=9600; len(to_visit)=142067
# num_visits=9700; len(to_visit)=143518
# num_visits=9800; len(to_visit)=144520
# num_visits=9900; len(to_visit)=145484
# num_visits=10000; len(to_visit)=146993
# num_visits=10100; len(to_visit)=148489
# num_visits=10200; len(to_visit)=149880
# num_visits=10300; len(to_visit)=151240
# num_visits=10400; len(to_visit)=153100
# num_visits=10500; len(to_visit)=154219
# num_visits=10600; len(to_visit)=155384
# num_visits=10700; len(to_visit)=156535
# num_visits=10800; len(to_visit)=157672
# num_visits=10900; len(to_visit)=158764
# num_visits=11000; len(to_visit)=160626
# num_visits=11100; len(to_visit)=162392
# num_visits=11200; len(to_visit)=163781
# num_visits=11300; len(to_visit)=165268
# num_visits=11400; len(to_visit)=166459
# num_visits=11500; len(to_visit)=167749
# num_visits=11600; len(to_visit)=168981
# num_visits=11700; len(to_visit)=170307
# num_visits=11800; len(to_visit)=171758
# num_visits=11900; len(to_visit)=173319
# num_visits=12000; len(to_visit)=174938
# num_visits=12100; len(to_visit)=176372
# num_visits=12200; len(to_visit)=177665
# num_visits=12300; len(to_visit)=178726
# num_visits=12400; len(to_visit)=180116
# num_visits=12500; len(to_visit)=181178
# num_visits=12600; len(to_visit)=182406
# num_visits=12700; len(to_visit)=183610
# num_visits=12800; len(to_visit)=184660
# num_visits=12900; len(to_visit)=185514
# num_visits=13000; len(to_visit)=186489
# num_visits=13100; len(to_visit)=187455
# num_visits=13200; len(to_visit)=188281
# num_visits=13300; len(to_visit)=189377
# num_visits=13400; len(to_visit)=190410
# num_visits=13500; len(to_visit)=191785
# num_visits=13600; len(to_visit)=192653
# num_visits=13700; len(to_visit)=193497
# num_visits=13800; len(to_visit)=194178
# num_visits=13900; len(to_visit)=194978
# num_visits=14000; len(to_visit)=195810
# num_visits=14100; len(to_visit)=196720
# num_visits=14200; len(to_visit)=197448
# num_visits=14300; len(to_visit)=198629
# num_visits=14400; len(to_visit)=199487
# num_visits=14500; len(to_visit)=200537
# num_visits=14600; len(to_visit)=201425
# num_visits=14700; len(to_visit)=202343
# num_visits=14800; len(to_visit)=203041
# num_visits=14900; len(to_visit)=203744
# num_visits=15000; len(to_visit)=204759
# num_visits=15100; len(to_visit)=205633
# num_visits=15200; len(to_visit)=207626
# num_visits=15300; len(to_visit)=208675
# num_visits=15400; len(to_visit)=209688
# num_visits=15500; len(to_visit)=210605
# num_visits=15600; len(to_visit)=211418
# num_visits=15700; len(to_visit)=212144
# num_visits=15800; len(to_visit)=213563
# num_visits=15900; len(to_visit)=214828
# num_visits=16000; len(to_visit)=215373
# num_visits=16100; len(to_visit)=217108
# num_visits=16200; len(to_visit)=218047
# num_visits=16300; len(to_visit)=219642
# num_visits=16400; len(to_visit)=220673
# num_visits=16500; len(to_visit)=221756
# num_visits=16600; len(to_visit)=223245
# num_visits=16700; len(to_visit)=224675
# num_visits=16800; len(to_visit)=225509
# num_visits=16900; len(to_visit)=226097
# num_visits=17000; len(to_visit)=227126
# num_visits=17100; len(to_visit)=228060
# num_visits=17200; len(to_visit)=229136
# num_visits=17300; len(to_visit)=230146
# num_visits=17400; len(to_visit)=231490
# num_visits=17500; len(to_visit)=232515
# num_visits=17600; len(to_visit)=233528
# num_visits=17700; len(to_visit)=234681
# num_visits=17800; len(to_visit)=235934
# num_visits=17900; len(to_visit)=236836
# num_visits=18000; len(to_visit)=237862
# num_visits=18100; len(to_visit)=238730
# num_visits=18200; len(to_visit)=239575
# num_visits=18300; len(to_visit)=240663
# num_visits=18400; len(to_visit)=242074
# num_visits=18500; len(to_visit)=243198
# num_visits=18600; len(to_visit)=244034
# num_visits=18700; len(to_visit)=244911
# num_visits=18800; len(to_visit)=245493
# num_visits=18900; len(to_visit)=246540
# num_visits=19000; len(to_visit)=247163
# num_visits=19100; len(to_visit)=248154
# num_visits=19200; len(to_visit)=249445
# num_visits=19300; len(to_visit)=250656
# num_visits=19400; len(to_visit)=251990
# num_visits=19500; len(to_visit)=252755
# num_visits=19600; len(to_visit)=253338
# num_visits=19700; len(to_visit)=254460
# num_visits=19800; len(to_visit)=255819
# num_visits=19900; len(to_visit)=257260
# num_visits=20000; len(to_visit)=258763
# num_visits=20100; len(to_visit)=259907
# num_visits=20200; len(to_visit)=261183
# num_visits=20300; len(to_visit)=262467
# num_visits=20400; len(to_visit)=264362
# num_visits=20500; len(to_visit)=265228
# num_visits=20600; len(to_visit)=266262
# couldn't find anything for page='Answering_the_Question:_What_Is_Enlightenment%3F'
# num_visits=20700; len(to_visit)=267540
# num_visits=20800; len(to_visit)=268969
# num_visits=20900; len(to_visit)=270684
# num_visits=21000; len(to_visit)=272188
# num_visits=21100; len(to_visit)=273616
# num_visits=21200; len(to_visit)=274904
# num_visits=21300; len(to_visit)=276471
# num_visits=21400; len(to_visit)=277867
# num_visits=21500; len(to_visit)=279355
# num_visits=21600; len(to_visit)=280495
# num_visits=21700; len(to_visit)=282006
# num_visits=21800; len(to_visit)=282689
# num_visits=21900; len(to_visit)=283424
# num_visits=22000; len(to_visit)=284288
# num_visits=22100; len(to_visit)=285222
# num_visits=22200; len(to_visit)=286089
# num_visits=22300; len(to_visit)=287395
# num_visits=22400; len(to_visit)=288263
# num_visits=22500; len(to_visit)=288824
# num_visits=22600; len(to_visit)=289748
# num_visits=22700; len(to_visit)=290578
# num_visits=22800; len(to_visit)=291477
# num_visits=22900; len(to_visit)=292209
# num_visits=23000; len(to_visit)=293388
# num_visits=23100; len(to_visit)=294106
# num_visits=23200; len(to_visit)=294872
# num_visits=23300; len(to_visit)=295694
# num_visits=23400; len(to_visit)=296282
# num_visits=23500; len(to_visit)=296882
# num_visits=23600; len(to_visit)=298009
# num_visits=23700; len(to_visit)=298832
# num_visits=23800; len(to_visit)=299389
# num_visits=23900; len(to_visit)=300325
# num_visits=24000; len(to_visit)=300937
# num_visits=24100; len(to_visit)=301798
# num_visits=24200; len(to_visit)=302349
# num_visits=24300; len(to_visit)=302821
# num_visits=24400; len(to_visit)=303386
# num_visits=24500; len(to_visit)=304037
# num_visits=24600; len(to_visit)=304870
# num_visits=24700; len(to_visit)=305725
# num_visits=24800; len(to_visit)=306353
# num_visits=24900; len(to_visit)=307276
# num_visits=25000; len(to_visit)=308430
# num_visits=25100; len(to_visit)=309808
# num_visits=25200; len(to_visit)=311375
# num_visits=25300; len(to_visit)=312180
# num_visits=25400; len(to_visit)=313590
# num_visits=25500; len(to_visit)=315060
# num_visits=25600; len(to_visit)=316698
# num_visits=25700; len(to_visit)=318298
# num_visits=25800; len(to_visit)=319824
# num_visits=25900; len(to_visit)=321354
# num_visits=26000; len(to_visit)=323185
# num_visits=26100; len(to_visit)=324306
# num_visits=26200; len(to_visit)=325581
# num_visits=26300; len(to_visit)=327192
# num_visits=26400; len(to_visit)=328197
# num_visits=26500; len(to_visit)=329906
# num_visits=26600; len(to_visit)=331219
# num_visits=26700; len(to_visit)=332259
# num_visits=26800; len(to_visit)=333439
# num_visits=26900; len(to_visit)=334494
# num_visits=27000; len(to_visit)=335465
# num_visits=27100; len(to_visit)=336652
# num_visits=27200; len(to_visit)=337734
# num_visits=27300; len(to_visit)=338935
# num_visits=27400; len(to_visit)=339906
# num_visits=27500; len(to_visit)=341162
# num_visits=27600; len(to_visit)=342034
# num_visits=27700; len(to_visit)=343395
# num_visits=27800; len(to_visit)=344282
# num_visits=27900; len(to_visit)=345385
# num_visits=28000; len(to_visit)=346428
# num_visits=28100; len(to_visit)=347886
# num_visits=28200; len(to_visit)=348602
# num_visits=28300; len(to_visit)=349517
# num_visits=28400; len(to_visit)=350421
# num_visits=28500; len(to_visit)=351423
# num_visits=28600; len(to_visit)=352740
# num_visits=28700; len(to_visit)=354196
# num_visits=28800; len(to_visit)=355353
# num_visits=28900; len(to_visit)=356909
# num_visits=29000; len(to_visit)=357801
# num_visits=29100; len(to_visit)=358529
# num_visits=29200; len(to_visit)=359160
# num_visits=29300; len(to_visit)=359947
# num_visits=29400; len(to_visit)=360631
# num_visits=29500; len(to_visit)=361439
# num_visits=29600; len(to_visit)=362240
# num_visits=29700; len(to_visit)=363072
# num_visits=29800; len(to_visit)=364059
# num_visits=29900; len(to_visit)=364732
# num_visits=30000; len(to_visit)=365801
# num_visits=30100; len(to_visit)=366799
# num_visits=30200; len(to_visit)=367749
# num_visits=30300; len(to_visit)=368913
# num_visits=30400; len(to_visit)=369818
# num_visits=30500; len(to_visit)=370771
# num_visits=30600; len(to_visit)=371516
# num_visits=30700; len(to_visit)=372225
# num_visits=30800; len(to_visit)=372889
# num_visits=30900; len(to_visit)=373511
# num_visits=31000; len(to_visit)=374399
# num_visits=31100; len(to_visit)=375113
# num_visits=31200; len(to_visit)=375731
# num_visits=31300; len(to_visit)=376249
# num_visits=31400; len(to_visit)=377035
# num_visits=31500; len(to_visit)=377508
# num_visits=31600; len(to_visit)=378178
# num_visits=31700; len(to_visit)=378583
# num_visits=31800; len(to_visit)=379061
# num_visits=31900; len(to_visit)=380144
# num_visits=32000; len(to_visit)=381327
# num_visits=32100; len(to_visit)=382927
# num_visits=32200; len(to_visit)=383884
# num_visits=32300; len(to_visit)=384707
# num_visits=32400; len(to_visit)=385632
# num_visits=32500; len(to_visit)=386467
# num_visits=32600; len(to_visit)=387409
# num_visits=32700; len(to_visit)=388635
# num_visits=32800; len(to_visit)=389381
# num_visits=32900; len(to_visit)=390405
# num_visits=33000; len(to_visit)=391349
# num_visits=33100; len(to_visit)=392091
# num_visits=33200; len(to_visit)=392789
# num_visits=33300; len(to_visit)=393537
# num_visits=33400; len(to_visit)=394267
# num_visits=33500; len(to_visit)=394825
# num_visits=33600; len(to_visit)=395645
# num_visits=33700; len(to_visit)=396257
# num_visits=33800; len(to_visit)=396793
# num_visits=33900; len(to_visit)=397355
# num_visits=34000; len(to_visit)=397989
# num_visits=34100; len(to_visit)=399161
# num_visits=34200; len(to_visit)=400171
# num_visits=34300; len(to_visit)=400998
# num_visits=34400; len(to_visit)=402156
# num_visits=34500; len(to_visit)=403220
# num_visits=34600; len(to_visit)=404114
# num_visits=34700; len(to_visit)=404788
# num_visits=34800; len(to_visit)=405680
# num_visits=34900; len(to_visit)=407045
# num_visits=35000; len(to_visit)=408236
# num_visits=35100; len(to_visit)=408917
# num_visits=35200; len(to_visit)=409842
# num_visits=35300; len(to_visit)=410905
# num_visits=35400; len(to_visit)=411877
# num_visits=35500; len(to_visit)=412807
# num_visits=35600; len(to_visit)=413545
# num_visits=35700; len(to_visit)=414299
# num_visits=35800; len(to_visit)=415108
# num_visits=35900; len(to_visit)=415901
# num_visits=36000; len(to_visit)=416580
# num_visits=36100; len(to_visit)=417227
# num_visits=36200; len(to_visit)=418221
# num_visits=36300; len(to_visit)=419174
# num_visits=36400; len(to_visit)=420159
# num_visits=36500; len(to_visit)=420725
# num_visits=36600; len(to_visit)=421393
# num_visits=36700; len(to_visit)=422006
# num_visits=36800; len(to_visit)=422621
# num_visits=36900; len(to_visit)=423378
# num_visits=37000; len(to_visit)=424622
# num_visits=37100; len(to_visit)=425225
# num_visits=37200; len(to_visit)=425708
# num_visits=37300; len(to_visit)=426233
# num_visits=37400; len(to_visit)=427195
# num_visits=37500; len(to_visit)=427842
# num_visits=37600; len(to_visit)=428215
# num_visits=37700; len(to_visit)=428882
# num_visits=37800; len(to_visit)=429575
# num_visits=37900; len(to_visit)=430190
# num_visits=38000; len(to_visit)=430746
# num_visits=38100; len(to_visit)=431408
# num_visits=38200; len(to_visit)=432190
# num_visits=38300; len(to_visit)=432703
# num_visits=38400; len(to_visit)=433013
# num_visits=38500; len(to_visit)=433901
# num_visits=38600; len(to_visit)=434851
# num_visits=38700; len(to_visit)=435352
# num_visits=38800; len(to_visit)=435801
# num_visits=38900; len(to_visit)=437109
# num_visits=39000; len(to_visit)=437659
# num_visits=39100; len(to_visit)=438327
# num_visits=39200; len(to_visit)=438807
# num_visits=39300; len(to_visit)=439383
# num_visits=39400; len(to_visit)=440460
# num_visits=39500; len(to_visit)=441504
# num_visits=39600; len(to_visit)=441953
# num_visits=39700; len(to_visit)=442591
# num_visits=39800; len(to_visit)=443287
# num_visits=39900; len(to_visit)=443790
# num_visits=40000; len(to_visit)=444288
# num_visits=40100; len(to_visit)=445301
# num_visits=40200; len(to_visit)=446068
# num_visits=40300; len(to_visit)=446616
# num_visits=40400; len(to_visit)=446919
# num_visits=40500; len(to_visit)=447346
# num_visits=40600; len(to_visit)=448067
# num_visits=40700; len(to_visit)=448994
# num_visits=40800; len(to_visit)=449294
# num_visits=40900; len(to_visit)=449635
# num_visits=41000; len(to_visit)=450094
# num_visits=41100; len(to_visit)=450692
# num_visits=41200; len(to_visit)=451318
# num_visits=41300; len(to_visit)=451915
# num_visits=41400; len(to_visit)=452820
# num_visits=41500; len(to_visit)=453956
# num_visits=41600; len(to_visit)=454437
# num_visits=41700; len(to_visit)=455001
# num_visits=41800; len(to_visit)=455649
# num_visits=41900; len(to_visit)=456155
# num_visits=42000; len(to_visit)=456563
# num_visits=42100; len(to_visit)=457011
# num_visits=42200; len(to_visit)=457325
# num_visits=42300; len(to_visit)=457842
# num_visits=42400; len(to_visit)=458304
# num_visits=42500; len(to_visit)=458665
# num_visits=42600; len(to_visit)=460332
# num_visits=42700; len(to_visit)=461198
# num_visits=42800; len(to_visit)=462471
# num_visits=42900; len(to_visit)=463583
# num_visits=43000; len(to_visit)=464645
# num_visits=43100; len(to_visit)=465834
# num_visits=43200; len(to_visit)=467045
# num_visits=43300; len(to_visit)=467962
# num_visits=43400; len(to_visit)=469310
# num_visits=43500; len(to_visit)=470612
# num_visits=43600; len(to_visit)=471369
# num_visits=43700; len(to_visit)=472229
# num_visits=43800; len(to_visit)=473587
# num_visits=43900; len(to_visit)=475028
# num_visits=44000; len(to_visit)=475652
# num_visits=44100; len(to_visit)=476439
# num_visits=44200; len(to_visit)=476711
# num_visits=44300; len(to_visit)=477239
# num_visits=44400; len(to_visit)=478344
# num_visits=44500; len(to_visit)=478984
# num_visits=44600; len(to_visit)=479414
# num_visits=44700; len(to_visit)=479915
# num_visits=44800; len(to_visit)=480400
# num_visits=44900; len(to_visit)=480902
# num_visits=45000; len(to_visit)=481850
# num_visits=45100; len(to_visit)=482947
# num_visits=45200; len(to_visit)=484205
# num_visits=45300; len(to_visit)=484781
# num_visits=45400; len(to_visit)=485259
# num_visits=45500; len(to_visit)=485919
# num_visits=45600; len(to_visit)=486351
# num_visits=45700; len(to_visit)=486975
# num_visits=45800; len(to_visit)=488273
# num_visits=45900; len(to_visit)=488991
# num_visits=46000; len(to_visit)=489572
# num_visits=46100; len(to_visit)=490146
# num_visits=46200; len(to_visit)=490924
# num_visits=46300; len(to_visit)=491520
# num_visits=46400; len(to_visit)=492145
# num_visits=46500; len(to_visit)=492723
# num_visits=46600; len(to_visit)=493727
# num_visits=46700; len(to_visit)=494544
# num_visits=46800; len(to_visit)=495756
# num_visits=46900; len(to_visit)=497815
# num_visits=47000; len(to_visit)=498479
# num_visits=47100; len(to_visit)=499049
# num_visits=47200; len(to_visit)=500377
# num_visits=47300; len(to_visit)=501778
# num_visits=47400; len(to_visit)=502389
# num_visits=47500; len(to_visit)=503173
# num_visits=47600; len(to_visit)=503432
# num_visits=47700; len(to_visit)=503993
# num_visits=47800; len(to_visit)=505010
# num_visits=47900; len(to_visit)=505634
# num_visits=48000; len(to_visit)=506085
# num_visits=48100; len(to_visit)=506535
# num_visits=48200; len(to_visit)=507084
# num_visits=48300; len(to_visit)=507646
# num_visits=48400; len(to_visit)=508302
# num_visits=48500; len(to_visit)=508904
# num_visits=48600; len(to_visit)=509605
# num_visits=48700; len(to_visit)=510120
# num_visits=48800; len(to_visit)=511138
# num_visits=48900; len(to_visit)=512215
# num_visits=49000; len(to_visit)=513469
# num_visits=49100; len(to_visit)=514160
# num_visits=49200; len(to_visit)=514872
# num_visits=49300; len(to_visit)=515461
# num_visits=49400; len(to_visit)=516060
# num_visits=49500; len(to_visit)=516650
# num_visits=49600; len(to_visit)=517609
# num_visits=49700; len(to_visit)=518432
# num_visits=49800; len(to_visit)=519631
# num_visits=49900; len(to_visit)=521629
# num_visits=50000; len(to_visit)=522233
# num_visits=50100; len(to_visit)=522611
# num_visits=50200; len(to_visit)=523713
# num_visits=50300; len(to_visit)=524157
# num_visits=50400; len(to_visit)=524466
# num_visits=50500; len(to_visit)=524846
# num_visits=50600; len(to_visit)=525377
# num_visits=50700; len(to_visit)=525952
# num_visits=50800; len(to_visit)=526979
# num_visits=50900; len(to_visit)=527677
# num_visits=51000; len(to_visit)=528467
# num_visits=51100; len(to_visit)=528987
# num_visits=51200; len(to_visit)=529861
# num_visits=51300; len(to_visit)=530600
# num_visits=51400; len(to_visit)=531722
# num_visits=51500; len(to_visit)=532664
# num_visits=51600; len(to_visit)=533501
# num_visits=51700; len(to_visit)=534116
# num_visits=51800; len(to_visit)=534583
# num_visits=51900; len(to_visit)=535205
# num_visits=52000; len(to_visit)=536085
# num_visits=52100; len(to_visit)=536791
# num_visits=52200; len(to_visit)=537575
# num_visits=52300; len(to_visit)=538509
# num_visits=52400; len(to_visit)=539458
# num_visits=52500; len(to_visit)=540378
# num_visits=52600; len(to_visit)=541265
# num_visits=52700; len(to_visit)=541762
# num_visits=52800; len(to_visit)=542133
# num_visits=52900; len(to_visit)=542754
# num_visits=53000; len(to_visit)=543322
# num_visits=53100; len(to_visit)=543849
# num_visits=53200; len(to_visit)=544500
# num_visits=53300; len(to_visit)=545258
# num_visits=53400; len(to_visit)=545587
# num_visits=53500; len(to_visit)=546080
# num_visits=53600; len(to_visit)=547148
# num_visits=53700; len(to_visit)=547700
# num_visits=53800; len(to_visit)=548753
# num_visits=53900; len(to_visit)=549225
# num_visits=54000; len(to_visit)=549845
# num_visits=54100; len(to_visit)=550302
# num_visits=54200; len(to_visit)=551067
# num_visits=54300; len(to_visit)=552244
# num_visits=54400; len(to_visit)=552798
# num_visits=54500; len(to_visit)=553461
# num_visits=54600; len(to_visit)=554028
# num_visits=54700; len(to_visit)=554575
# num_visits=54800; len(to_visit)=555473
# num_visits=54900; len(to_visit)=556386
# num_visits=55000; len(to_visit)=556838
# num_visits=55100; len(to_visit)=557362
# num_visits=55200; len(to_visit)=557878
# num_visits=55300; len(to_visit)=558572
# num_visits=55400; len(to_visit)=559068
# num_visits=55500; len(to_visit)=559637
# num_visits=55600; len(to_visit)=560132
# num_visits=55700; len(to_visit)=560509
# num_visits=55800; len(to_visit)=560917
# num_visits=55900; len(to_visit)=561802
# num_visits=56000; len(to_visit)=562787
# num_visits=56100; len(to_visit)=563416
# num_visits=56200; len(to_visit)=564234
# num_visits=56300; len(to_visit)=564913
# num_visits=56400; len(to_visit)=565568
# num_visits=56500; len(to_visit)=566595
# num_visits=56600; len(to_visit)=567295
# num_visits=56700; len(to_visit)=568245
# num_visits=56800; len(to_visit)=569056
# num_visits=56900; len(to_visit)=569585
# num_visits=57000; len(to_visit)=570312
# num_visits=57100; len(to_visit)=571000
# num_visits=57200; len(to_visit)=571540
# num_visits=57300; len(to_visit)=572324
# num_visits=57400; len(to_visit)=572883
# num_visits=57500; len(to_visit)=573474
# num_visits=57600; len(to_visit)=573955
# num_visits=57700; len(to_visit)=574939
# num_visits=57800; len(to_visit)=575880
# num_visits=57900; len(to_visit)=576689
# num_visits=58000; len(to_visit)=577789
# num_visits=58100; len(to_visit)=578719
# num_visits=58200; len(to_visit)=579341
# num_visits=58300; len(to_visit)=580053
# num_visits=58400; len(to_visit)=581270
# num_visits=58500; len(to_visit)=582299
# num_visits=58600; len(to_visit)=582929
# num_visits=58700; len(to_visit)=583846
# num_visits=58800; len(to_visit)=584665
# num_visits=58900; len(to_visit)=585610
# num_visits=59000; len(to_visit)=586373
# num_visits=59100; len(to_visit)=587023
# num_visits=59200; len(to_visit)=587721
# num_visits=59300; len(to_visit)=588579
# num_visits=59400; len(to_visit)=589287
# num_visits=59500; len(to_visit)=589963
# num_visits=59600; len(to_visit)=590779
# num_visits=59700; len(to_visit)=591684
# num_visits=59800; len(to_visit)=592413
# num_visits=59900; len(to_visit)=593005
# num_visits=60000; len(to_visit)=593666
# num_visits=60100; len(to_visit)=594150
# num_visits=60200; len(to_visit)=594729
# num_visits=60300; len(to_visit)=595869
# num_visits=60400; len(to_visit)=596718
# num_visits=60500; len(to_visit)=597375
# num_visits=60600; len(to_visit)=598078
# num_visits=60700; len(to_visit)=598413
# num_visits=60800; len(to_visit)=599375
# num_visits=60900; len(to_visit)=600186
# num_visits=61000; len(to_visit)=601038
# num_visits=61100; len(to_visit)=601608
# num_visits=61200; len(to_visit)=602529
# num_visits=61300; len(to_visit)=603697
# num_visits=61400; len(to_visit)=604385
# num_visits=61500; len(to_visit)=605473
# num_visits=61600; len(to_visit)=606246
# num_visits=61700; len(to_visit)=606918
# num_visits=61800; len(to_visit)=607764
# num_visits=61900; len(to_visit)=608301
# num_visits=62000; len(to_visit)=608831
# num_visits=62100; len(to_visit)=609967
# num_visits=62200; len(to_visit)=610897
# num_visits=62300; len(to_visit)=611659
# num_visits=62400; len(to_visit)=612512
# num_visits=62500; len(to_visit)=613339
# num_visits=62600; len(to_visit)=613883
# num_visits=62700; len(to_visit)=614764
# num_visits=62800; len(to_visit)=615602
# num_visits=62900; len(to_visit)=616502
# num_visits=63000; len(to_visit)=617237
# num_visits=63100; len(to_visit)=618049
# num_visits=63200; len(to_visit)=618640
# num_visits=63300; len(to_visit)=619474
# num_visits=63400; len(to_visit)=620633
# num_visits=63500; len(to_visit)=621525
# num_visits=63600; len(to_visit)=622472
# num_visits=63700; len(to_visit)=623229
# num_visits=63800; len(to_visit)=624000
# num_visits=63900; len(to_visit)=624856
# num_visits=64000; len(to_visit)=626028
# num_visits=64100; len(to_visit)=627250
# num_visits=64200; len(to_visit)=627970
# num_visits=64300; len(to_visit)=628885
# num_visits=64400; len(to_visit)=629897
# num_visits=64500; len(to_visit)=630495
# num_visits=64600; len(to_visit)=631324
# num_visits=64700; len(to_visit)=632018
# num_visits=64800; len(to_visit)=632966
# num_visits=64900; len(to_visit)=633369
# num_visits=65000; len(to_visit)=633957
# num_visits=65100; len(to_visit)=634252
# num_visits=65200; len(to_visit)=635084
# num_visits=65300; len(to_visit)=636251
# num_visits=65400; len(to_visit)=637144
# num_visits=65500; len(to_visit)=637977
# num_visits=65600; len(to_visit)=638589
# num_visits=65700; len(to_visit)=639478
# num_visits=65800; len(to_visit)=639970
# num_visits=65900; len(to_visit)=640599
# num_visits=66000; len(to_visit)=641209
# num_visits=66100; len(to_visit)=642117
# num_visits=66200; len(to_visit)=642963
# num_visits=66300; len(to_visit)=644129
# num_visits=66400; len(to_visit)=644693
# num_visits=66500; len(to_visit)=645485
# num_visits=66600; len(to_visit)=646217
# num_visits=66700; len(to_visit)=646929
# num_visits=66800; len(to_visit)=647581
# num_visits=66900; len(to_visit)=647968
# num_visits=67000; len(to_visit)=648256
# num_visits=67100; len(to_visit)=648917
# num_visits=67200; len(to_visit)=649870
# num_visits=67300; len(to_visit)=651009
# num_visits=67400; len(to_visit)=652332
# num_visits=67500; len(to_visit)=652889
# num_visits=67600; len(to_visit)=653565
# num_visits=67700; len(to_visit)=654133
# num_visits=67800; len(to_visit)=654720
# num_visits=67900; len(to_visit)=655901
# num_visits=68000; len(to_visit)=656479
# num_visits=68100; len(to_visit)=657126
# num_visits=68200; len(to_visit)=657714
# num_visits=68300; len(to_visit)=658576
# num_visits=68400; len(to_visit)=659547
# num_visits=68500; len(to_visit)=660233
# num_visits=68600; len(to_visit)=660601
# num_visits=68700; len(to_visit)=661113
# num_visits=68800; len(to_visit)=661694
# num_visits=68900; len(to_visit)=662098
# num_visits=69000; len(to_visit)=662732
# num_visits=69100; len(to_visit)=663595
# num_visits=69200; len(to_visit)=664242
# num_visits=69300; len(to_visit)=664741
# num_visits=69400; len(to_visit)=665257
# num_visits=69500; len(to_visit)=665908
# num_visits=69600; len(to_visit)=666567
# num_visits=69700; len(to_visit)=667049
# num_visits=69800; len(to_visit)=667779
# num_visits=69900; len(to_visit)=668412
# num_visits=70000; len(to_visit)=669150
# num_visits=70100; len(to_visit)=669895
# num_visits=70200; len(to_visit)=670625
# num_visits=70300; len(to_visit)=671267
# num_visits=70400; len(to_visit)=671903
# num_visits=70500; len(to_visit)=673177
# num_visits=70600; len(to_visit)=674127
# num_visits=70700; len(to_visit)=675347
# num_visits=70800; len(to_visit)=676366
# num_visits=70900; len(to_visit)=677278
# couldn't find anything for page='Answering_the_Question:_What_Is_Enlightenment%3F'
# num_visits=71000; len(to_visit)=678149
# num_visits=71100; len(to_visit)=678564
# num_visits=71200; len(to_visit)=679081
# num_visits=71300; len(to_visit)=679706
# num_visits=71400; len(to_visit)=680389
# num_visits=71500; len(to_visit)=681095
# num_visits=71600; len(to_visit)=681726
# num_visits=71700; len(to_visit)=682352
# num_visits=71800; len(to_visit)=682813
# num_visits=71900; len(to_visit)=683400
# num_visits=72000; len(to_visit)=683859
# num_visits=72100; len(to_visit)=684360
# num_visits=72200; len(to_visit)=684906
# num_visits=72300; len(to_visit)=685940
# num_visits=72400; len(to_visit)=686727
# num_visits=72500; len(to_visit)=687297
# num_visits=72600; len(to_visit)=688196
# num_visits=72700; len(to_visit)=689126
# num_visits=72800; len(to_visit)=689907
# num_visits=72900; len(to_visit)=690837
# num_visits=73000; len(to_visit)=691740
# num_visits=73100; len(to_visit)=692485
# num_visits=73200; len(to_visit)=693763
# num_visits=73300; len(to_visit)=694968
# num_visits=73400; len(to_visit)=695793
# num_visits=73500; len(to_visit)=697035
# num_visits=73600; len(to_visit)=698066
# num_visits=73700; len(to_visit)=699024
# num_visits=73800; len(to_visit)=700162
# num_visits=73900; len(to_visit)=701514
# num_visits=74000; len(to_visit)=702386
# num_visits=74100; len(to_visit)=703209
# num_visits=74200; len(to_visit)=703821
# num_visits=74300; len(to_visit)=704627
# num_visits=74400; len(to_visit)=705140
# num_visits=74500; len(to_visit)=705633
# num_visits=74600; len(to_visit)=706487
# num_visits=74700; len(to_visit)=707726
# num_visits=74800; len(to_visit)=708280
# num_visits=74900; len(to_visit)=708876
# num_visits=75000; len(to_visit)=709866
# num_visits=75100; len(to_visit)=710550
# num_visits=75200; len(to_visit)=711105
# num_visits=75300; len(to_visit)=711915
# num_visits=75400; len(to_visit)=712741
# num_visits=75500; len(to_visit)=713279
# num_visits=75600; len(to_visit)=714005
# num_visits=75700; len(to_visit)=715062
# num_visits=75800; len(to_visit)=715709
# num_visits=75900; len(to_visit)=716537
# num_visits=76000; len(to_visit)=717130
# num_visits=76100; len(to_visit)=717861
# num_visits=76200; len(to_visit)=718978
# couldn't find anything for page='Answering_the_Question:_What_Is_Enlightenment%3F'
# num_visits=76300; len(to_visit)=719696
# num_visits=76400; len(to_visit)=720703
# num_visits=76500; len(to_visit)=721650
# num_visits=76600; len(to_visit)=723133
# num_visits=76700; len(to_visit)=724405
# num_visits=76800; len(to_visit)=725497
# num_visits=76900; len(to_visit)=726780
# num_visits=77000; len(to_visit)=727626
# num_visits=77100; len(to_visit)=728954
# num_visits=77200; len(to_visit)=730153
# num_visits=77300; len(to_visit)=731969
# num_visits=77400; len(to_visit)=733184
# num_visits=77500; len(to_visit)=734111
# num_visits=77600; len(to_visit)=735349
# num_visits=77700; len(to_visit)=736251
# num_visits=77800; len(to_visit)=737048
# couldn't find anything for page='Answering_the_Question:_What_Is_Enlightenment%3F'
# num_visits=77900; len(to_visit)=738117
# num_visits=78000; len(to_visit)=738904
# num_visits=78100; len(to_visit)=739133
# num_visits=78200; len(to_visit)=739961
# num_visits=78300; len(to_visit)=740565
# num_visits=78400; len(to_visit)=741382
# num_visits=78500; len(to_visit)=742389
# num_visits=78600; len(to_visit)=743411
# num_visits=78700; len(to_visit)=744458
# num_visits=78800; len(to_visit)=745493
# num_visits=78900; len(to_visit)=746541
# num_visits=79000; len(to_visit)=747730
# num_visits=79100; len(to_visit)=748531
# num_visits=79200; len(to_visit)=749282
# num_visits=79300; len(to_visit)=750355
# num_visits=79400; len(to_visit)=751127
# num_visits=79500; len(to_visit)=752214
# num_visits=79600; len(to_visit)=753137
# num_visits=79700; len(to_visit)=754012
# num_visits=79800; len(to_visit)=754469
# num_visits=79900; len(to_visit)=755060
# num_visits=80000; len(to_visit)=755783
# num_visits=80100; len(to_visit)=756209
# num_visits=80200; len(to_visit)=757134
# num_visits=80300; len(to_visit)=758226
# num_visits=80400; len(to_visit)=758999
# num_visits=80500; len(to_visit)=759905
# num_visits=80600; len(to_visit)=760692
# num_visits=80700; len(to_visit)=761172
# num_visits=80800; len(to_visit)=762090
# num_visits=80900; len(to_visit)=762877
# num_visits=81000; len(to_visit)=763152
# num_visits=81100; len(to_visit)=763659
# num_visits=81200; len(to_visit)=764440
# num_visits=81300; len(to_visit)=765033
# num_visits=81400; len(to_visit)=765771
# num_visits=81500; len(to_visit)=766478
# num_visits=81600; len(to_visit)=768218
# num_visits=81700; len(to_visit)=770175
# num_visits=81800; len(to_visit)=772311
# num_visits=81900; len(to_visit)=773127
# num_visits=82000; len(to_visit)=774343
# num_visits=82100; len(to_visit)=775453
# num_visits=82200; len(to_visit)=776954
# num_visits=82300; len(to_visit)=778097
# num_visits=82400; len(to_visit)=779402
# num_visits=82500; len(to_visit)=780448
# num_visits=82600; len(to_visit)=781415
# num_visits=82700; len(to_visit)=782003
# num_visits=82800; len(to_visit)=782572
# num_visits=82900; len(to_visit)=783131
# num_visits=83000; len(to_visit)=783663
# num_visits=83100; len(to_visit)=784445
# num_visits=83200; len(to_visit)=785099
# num_visits=83300; len(to_visit)=785884
# num_visits=83400; len(to_visit)=786684
# num_visits=83500; len(to_visit)=787664
# num_visits=83600; len(to_visit)=788470
# num_visits=83700; len(to_visit)=789396
# num_visits=83800; len(to_visit)=790512
# num_visits=83900; len(to_visit)=791793
# num_visits=84000; len(to_visit)=792972
# num_visits=84100; len(to_visit)=793899
# num_visits=84200; len(to_visit)=794878
# num_visits=84300; len(to_visit)=796077
# num_visits=84400; len(to_visit)=797302
# num_visits=84500; len(to_visit)=798512
# num_visits=84600; len(to_visit)=799345
# num_visits=84700; len(to_visit)=800062
# num_visits=84800; len(to_visit)=800424
# num_visits=84900; len(to_visit)=800885
# num_visits=85000; len(to_visit)=801507
# num_visits=85100; len(to_visit)=802326
# num_visits=85200; len(to_visit)=803314
# num_visits=85300; len(to_visit)=804086
# num_visits=85400; len(to_visit)=804725
# num_visits=85500; len(to_visit)=805263
# num_visits=85600; len(to_visit)=805848
# num_visits=85700; len(to_visit)=806571
# num_visits=85800; len(to_visit)=807322
# num_visits=85900; len(to_visit)=807509
# num_visits=86000; len(to_visit)=808411
# num_visits=86100; len(to_visit)=808961
# num_visits=86200; len(to_visit)=809561
# num_visits=86300; len(to_visit)=810405
# num_visits=86400; len(to_visit)=811155
# num_visits=86500; len(to_visit)=811996
# num_visits=86600; len(to_visit)=812552
# num_visits=86700; len(to_visit)=813548
# num_visits=86800; len(to_visit)=814321
# num_visits=86900; len(to_visit)=815176
# num_visits=87000; len(to_visit)=815507
# num_visits=87100; len(to_visit)=816388
# num_visits=87200; len(to_visit)=817605
# num_visits=87300; len(to_visit)=818402
# num_visits=87400; len(to_visit)=819094
# num_visits=87500; len(to_visit)=820109
# num_visits=87600; len(to_visit)=821019
# num_visits=87700; len(to_visit)=821910
# num_visits=87800; len(to_visit)=822570
# num_visits=87900; len(to_visit)=823461
# num_visits=88000; len(to_visit)=824606
# num_visits=88100; len(to_visit)=825722
# num_visits=88200; len(to_visit)=826781
# num_visits=88300; len(to_visit)=827731
# num_visits=88400; len(to_visit)=828280
# num_visits=88500; len(to_visit)=828747
# num_visits=88600; len(to_visit)=829443
# num_visits=88700; len(to_visit)=830694
# num_visits=88800; len(to_visit)=831518
# num_visits=88900; len(to_visit)=832124
# num_visits=89000; len(to_visit)=832693
# num_visits=89100; len(to_visit)=833835
# num_visits=89200; len(to_visit)=834305
# num_visits=89300; len(to_visit)=835059
# num_visits=89400; len(to_visit)=836108
# num_visits=89500; len(to_visit)=837040
# num_visits=89600; len(to_visit)=837859
# num_visits=89700; len(to_visit)=838644
# num_visits=89800; len(to_visit)=839244
# num_visits=89900; len(to_visit)=840075
# num_visits=90000; len(to_visit)=841166
# num_visits=90100; len(to_visit)=842216
# num_visits=90200; len(to_visit)=843065
# num_visits=90300; len(to_visit)=843776
# num_visits=90400; len(to_visit)=844888
# num_visits=90500; len(to_visit)=845879
# num_visits=90600; len(to_visit)=847061
# num_visits=90700; len(to_visit)=847647
# num_visits=90800; len(to_visit)=848502
# num_visits=90900; len(to_visit)=849224
# num_visits=91000; len(to_visit)=850143
# num_visits=91100; len(to_visit)=850796
# couldn't find anything for page='Answering_the_Question:_What_Is_Enlightenment%3F'
# num_visits=91200; len(to_visit)=851607
# num_visits=91300; len(to_visit)=852257
# num_visits=91400; len(to_visit)=852492
# num_visits=91500; len(to_visit)=853094
# num_visits=91600; len(to_visit)=853655
# num_visits=91700; len(to_visit)=854116
# num_visits=91800; len(to_visit)=854725
# num_visits=91900; len(to_visit)=855054
# num_visits=92000; len(to_visit)=855636
# num_visits=92100; len(to_visit)=856647
# num_visits=92200; len(to_visit)=857120
# num_visits=92300; len(to_visit)=857583
# couldn't find anything for page='Answering_the_Question:_What_Is_Enlightenment%3F'
# num_visits=92400; len(to_visit)=858107
# num_visits=92500; len(to_visit)=858613
# num_visits=92600; len(to_visit)=859015
# num_visits=92700; len(to_visit)=859419
# num_visits=92800; len(to_visit)=860020
# couldn't find anything for page='Special:WhatLinksHere/Wikipedia:Accuracy_dispute'
# num_visits=92900; len(to_visit)=860295
# num_visits=93000; len(to_visit)=860650
# num_visits=93100; len(to_visit)=861151
# num_visits=93200; len(to_visit)=861713
# num_visits=93300; len(to_visit)=862332
# num_visits=93400; len(to_visit)=862760
# num_visits=93500; len(to_visit)=863386
# num_visits=93600; len(to_visit)=863917
# num_visits=93700; len(to_visit)=864532
# num_visits=93800; len(to_visit)=865373
# num_visits=93900; len(to_visit)=866145
# num_visits=94000; len(to_visit)=866757
# num_visits=94100; len(to_visit)=867219
# num_visits=94200; len(to_visit)=867679
# num_visits=94300; len(to_visit)=868188
# num_visits=94400; len(to_visit)=868675
# num_visits=94500; len(to_visit)=869299
# num_visits=94600; len(to_visit)=869727
# num_visits=94700; len(to_visit)=870358
# num_visits=94800; len(to_visit)=871078
# num_visits=94900; len(to_visit)=871381
# num_visits=95000; len(to_visit)=871637
# num_visits=95100; len(to_visit)=872102
# num_visits=95200; len(to_visit)=872945
# num_visits=95300; len(to_visit)=873637
# num_visits=95400; len(to_visit)=874298
# num_visits=95500; len(to_visit)=875095
# num_visits=95600; len(to_visit)=875659
# num_visits=95700; len(to_visit)=876465
# num_visits=95800; len(to_visit)=877311
# num_visits=95900; len(to_visit)=878281
# num_visits=96000; len(to_visit)=878929
# num_visits=96100; len(to_visit)=879284
# num_visits=96200; len(to_visit)=879644
# num_visits=96300; len(to_visit)=880110
# num_visits=96400; len(to_visit)=880723
# num_visits=96500; len(to_visit)=881437
# num_visits=96600; len(to_visit)=882077
# num_visits=96700; len(to_visit)=882748
# num_visits=96800; len(to_visit)=883488
# num_visits=96900; len(to_visit)=884324
# num_visits=97000; len(to_visit)=884810
# num_visits=97100; len(to_visit)=885139
# num_visits=97200; len(to_visit)=886383
# num_visits=97300; len(to_visit)=887033
# num_visits=97400; len(to_visit)=887693
# num_visits=97500; len(to_visit)=888272
# num_visits=97600; len(to_visit)=888947
# num_visits=97700; len(to_visit)=889345
# num_visits=97800; len(to_visit)=889628
# num_visits=97900; len(to_visit)=890066
# num_visits=98000; len(to_visit)=890631
# num_visits=98100; len(to_visit)=891202
# num_visits=98200; len(to_visit)=891715
# num_visits=98300; len(to_visit)=892147
# num_visits=98400; len(to_visit)=892598
# num_visits=98500; len(to_visit)=893095
# num_visits=98600; len(to_visit)=893771
# num_visits=98700; len(to_visit)=894315
# num_visits=98800; len(to_visit)=894989
# num_visits=98900; len(to_visit)=895510
# num_visits=99000; len(to_visit)=896154
# num_visits=99100; len(to_visit)=896647
# num_visits=99200; len(to_visit)=897376
# num_visits=99300; len(to_visit)=898347
# num_visits=99400; len(to_visit)=899259
# num_visits=99500; len(to_visit)=899548
# num_visits=99600; len(to_visit)=900342
# num_visits=99700; len(to_visit)=901383
# num_visits=99800; len(to_visit)=902329
# num_visits=99900; len(to_visit)=902952
# num_visits=100000; len(to_visit)=903492

# %%
len(johnny_graph)
# Out:
# 6747

# %%
len(douglas_loop)
# Out:
# 26799

# %%
import pickle
with open('douglas_loop.pickle', 'wb') as f:
    pickle.dump(douglas_loop, f)

# %%
def find_mutual_linkers(graph):
    edges = set()
    for page, linkees in graph.items():
        for linkee in linkees:
            if linkee not in graph:
                continue
            if page in graph[linkee]:
                edges.add(tuple(sorted([page, linkee])))
    return edges

# %%
def canonicalize_cycle(cycle):
    # we want to avoid duplication of cycles via different starting points
    # so we'll put the alphabetically first entry first in the cycle.
    earliest_i = 0
    for i, el in enumerate(cycle):
        if el < cycle[earliest_i]:
            earliest_i = i
    return cycle[earliest_i:] + cycle[:earliest_i]
            

def find_cycles(graph, n=2):
    # certainly this is not the most efficient cycle-finding algorithm. essentially brute force.
    cycles = set()
    def helper(potential_cycle):
        linkees = graph[potential_cycle[-1]] if potential_cycle[-1] in graph else []
        if len(potential_cycle) == n:
            if linkees and potential_cycle[0] in linkees:
                cycles.add(canonicalize_cycle(potential_cycle))
        else:
            for linkee in linkees:
                # no fake cycles!
                if linkee not in potential_cycle:
                    helper(potential_cycle + (linkee,))
    for page in tqdm.tqdm(graph.keys()):
        helper((page,))
    return cycles

# %%
len(find_cycles(douglas_loop, n=3))
# Out:
# 100%|██████████████████████████████████████████████████████████████████████| 26799/26799 [00:14<00:00, 1874.84it/s]
# 57818

# %%
potential_four_cycles = find_cycles(douglas_loop, n=4)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████| 26799/26799 [04:25<00:00, 100.87it/s]

# %%
driver = webdriver.Chrome()
driver.set_window_size(1200, 800)

# %%
def find_link_boxes_on_page(page, links):
    driver.get(url_from_page(page))
    time.sleep(.2)
    return driver.execute_script('''
const desirableSlugs = arguments[0]
const slugToBox = {}
document.querySelectorAll('.mw-parser-output p a').forEach(i => {
  const href = i.href
  const matches = href.match('/wiki/(.+)')
  
  // only take slugs we care about, and the first instance of it
  if (matches && matches.length > 1 && desirableSlugs.includes(matches[1]) && !(matches[1] in slugToBox)) {
    slugToBox[matches[1]] = i.getBoundingClientRect()
  }
})
return slugToBox
    ''', list(links))

def boxes_overlap(box_a, box_b):
    lefter, righter = sorted([box_a, box_b], key=lambda box: box['left'])
    upper, lower = sorted([box_a, box_b], key=lambda box: box['top'])
    # need the last two condition because boundary boxes get screwed up when a link crosses lines (box covers whole thing)
    return lefter['right'] > righter['left'] and upper['bottom'] > lower['top'] and lefter['height'] < 20 and righter['height'] < 20

def gather_boxes(cycles):
    page_to_links_we_want = defaultdict(set)
    pages_to_link_boxes = {}
    
    # group so we only process pages once
    for cycle in cycles:
        for i in range(len(cycle)):
            page_to_links_we_want[cycle[i]].add(cycle[(i + 1) % len(cycle)])
        
    # actually figure out where the links are
    for page, links in tqdm.tqdm(page_to_links_we_want.items()):
        try:
            pages_to_link_boxes[page] = find_link_boxes_on_page(page, links)
        except Exception as e:
            print(e)
            continue
    
    return pages_to_link_boxes

def evaluate_loopiness(cycles, pages_to_link_boxes):
    for cycle in cycles:
        try:
            if all(
                # note that we compare all to first link box, because boxes overlapping is not transitive
                boxes_overlap(
                    pages_to_link_boxes[cycle[0]][cycle[1]], 
                    pages_to_link_boxes[cycle[i + 1]][cycle[(i + 2) % len(cycle)]]
                )
                for i in range(len(cycle) - 1)
            ):
                print(cycle)
        except KeyError:
            pass

# %%
boxes = gather_boxes(edges)
# Out:
# 100%|████████████████████████| 3745/3745 [1:11:36<00:00,  1.15s/it]

# %%
more = gather_boxes(find_cycles(johnny_graph, n=4))
# Out:
# 100%|████████████████████████| 5046/5046 [1:08:07<00:00,  1.23it/s]

# %%
same_boxes = gather_boxes(find_cycles(johnny_graph, n=3))
# Out:
# 100%|██████████████████████████| 3909/3909 [52:52<00:00,  1.23it/s]

# %%
four_boxes = gather_boxes(potential_four_cycles)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████| 21570/21570 [3:55:55<00:00,  1.52it/s]

# %%
evaluate_loopiness(potential_four_cycles, four_boxes)
# Out:
# ('National_Academies_of_Sciences,_Engineering,_and_Medicine', 'National_Academy_of_Engineering', 'National_Academy_of_Medicine', 'National_Academy_of_Sciences')
# ('Animal', 'Heterotroph', 'Parasitic_plant', 'Plants')

# %%
evaluate_loopiness(find_cycles(johnny_graph, n=3), same_boxes)
# Out:
# ('Far_Eastern_Federal_District', 'Russian_Far_East', 'Khabarovsk')
# ('Farewell_to_the_Master', 'The_Day_the_Earth_Stood_Still_(2008_film)', 'Harry_Bates_(author)')
# ('Computer', 'Computer_network', 'Host_(network)')

# %%
list(range(2))
# Out:
# [0, 1]

# %%
evaluate_loopiness(edges, boxes)
# Out:
# ('Nebula_Award_for_Best_Novel', 'Nebula_Award_for_Best_Novelette')
# ('Emperor_of_Japan', 'Imperial_House_of_Japan')
# ('Bhutan', 'Nepal')
# ('Constitution_of_Japan', 'Occupation_of_Japan')
# ('Guozijian_(Beijing)', 'Peking_University')
# ('William_Clayton_(Arrowverse)', 'William_Clayton_(Arrowverse)')
# ('Altaic_languages', 'Tungusic_languages')
# ('Himalayas', 'Indian_subcontinent')
# ('Entertainment_industry', 'Entertainment_industry')
# ('Han_Yu', 'Neo-Confucianism')
# ('All_Tomorrow%27s_Parties_(novel)', 'Bridge_trilogy')
# ('Alabama', 'Florida')
# ('Hokkaido', 'Prefectures_of_Japan')
# ('Nationalist_government', 'Republic_of_China_(1912%E2%80%931949)')
# ('End_of_World_War_II_in_Asia', 'Surrender_of_Japan')
# ('British_Columbia', 'Population_of_Canada_by_province_and_territory')
# ('United_States_Air_Force', 'United_States_Armed_Forces')
# ('Hindu_Kush', 'South_Asia')
# ('New_York_(state)', 'Vermont')
# ('Mia_Smoak', 'Mia_Smoak')
# ('2008_Summer_Paralympics#Participating_NPCs', '2008_Summer_Paralympics#Participating_NPCs')
# ('Qatar', 'Saudi_Arabia')
# ('Perry_Expedition', 'Sakoku')
# ('Hong_Kong', 'Hong_Kong_Cantonese')
# ('Mahayana', 'Yogachara')
# ('New_Brunswick,_New_Jersey', 'Rutgers_University')
# ('Yue_(state)', 'Zhejiang')
# ('Central_Canada', 'Ontario')
# ('List_of_metropolitan_statistical_areas', 'Philadelphia')
# ('Roy_Harper_(Arrowverse)', 'Roy_Harper_(Arrowverse)')
# ('Empire_State_Building', 'Midtown_Manhattan')
# ('Derek_Kolstad', 'John_Wick_(film)')
# ('Spook_Country', 'Zero_History')
# ('The_Guardian', 'The_Guardian_Weekly')
# ('1911_Revolution', 'Dynasties_in_Chinese_history')
# ('Rink_bandy#Rinkball', 'Rink_bandy#Rinkball')
# ('Anatolia', 'Western_Asia')
# ('East_Asia', 'South_Korea')
# ('Taoism#Spelling_and_pronunciation', 'Taoism#Spelling_and_pronunciation')
# ('Americas', 'Europe')
# ('Elizabeth_Warren', 'Rutgers_Law_School')
# ('Blade_Runner', 'Ridley_Scott')
# ('Caroline_Bamberger_Fuld', 'Louis_Bamberger')
# ('Hanmun', 'Hanmun')
# ('Algorithm', 'Computer_science')
# ('Chen_Duxiu', 'Chinese_Communist_Party')
# ('Asset_management', 'Investment_management')
# ('Frederick_Stanley,_16th_Earl_of_Derby', 'Stanley_Cup')
# ('Carr%C3%A8re_and_Hastings', 'Thomas_Hastings_(architect)')
# ('Legends_of_Tomorrow', 'Marc_Guggenheim')
# ('Archaic_Greece', 'Greek_Dark_Ages')
# ('2016_United_States_presidential_election', 'Hillary_Clinton')
# ('Shanghai#Economy', 'Shanghai#Economy')
# ('Portuguese_Inquisition', 'Roman_Inquisition')
# ('South_Asia', 'South_Asian_Association_for_Regional_Cooperation')
# ('Eastern_Siberia', 'Eastern_Siberia')
# ('Iowa', 'Wisconsin')
# ('General_Secretary_of_the_Chinese_Communist_Party', 'Paramount_leader')
# ('Austria', 'Hungary')
# ('Seikan_Tunnel', 'Tsugaru_Strait')
# ('University_of_Newark', 'University_of_Newark')
# ('Korean_Demilitarized_Zone', 'South_Korea')
# ('11th_century', '2nd_millennium')
# ('Dungan_language', 'Xiao%27erjing')
# ('Chinese_Academy_of_Engineering', 'Li_Xiaohong')
# ('David_Scarpa', 'The_Day_the_Earth_Stood_Still_(2008_film)')
# ('Boroughs_of_New_York_City', 'The_Bronx')
# ('Cast_iron', 'Steel')
# ('Public_Service_Corporation', 'Public_Service_Enterprise_Group')
# ('Talia_al_Ghul_(Arrowverse)', 'Talia_al_Ghul_(Arrowverse)')
# ('Himalayas', 'Karakoram')
# ('Constantine_(film)', 'Kevin_Brodbin')
# ('Atlantic_Ocean', 'Europe')
# ('Shanghai#Education_and_research', 'Shanghai#Education_and_research')
# ('Myanmar', 'Thailand')
# ('Slovakia', 'Ukraine')
# ('Information_engineering_(field)', 'Information_theory')
# ('The_Matrix_(franchise)', 'The_Matrix_Revolutions')
# ('Government_of_New_York_City', 'New_York_City_Hall')
# ('Pinyin', 'Standard_Chinese')
# ('Quentin_Lance', 'Quentin_Lance')

# %%
# starting_page = 'Johnny_Mnemonic_(film)'

# %%
class WikipediaApiException(Exception):
    pass

def get_article(title):
    # see: https://stackoverflow.com/questions/7185288/how-can-i-get-wikipedia-content-using-wikipedias-api
    params = {
        'format': 'json',
        'action': 'query',
        'prop': 'revisions',
        'rvprop': 'content',
        'rvsection': 0,
        'rvslots': '*',
        'titles': title,
        'formatversion': 2,
    }
    r = requests.get(f'https://en.wikipedia.org/w/api.php', params=params)
#     return r
    if r.status_code != 200:
        raise WikipediaApiException(r)
    
    try:
        return r.json()['query']['pages'][0]['revisions'][0]['slots']['main']['content']
    except:
        raise WikipediaApiException(f'malformed data: {r.json()}')

# %%
def clean_article(text):
#     text = text.split('\n\n')[1]  # easiest way to get to start of real text, but imperfect (causing some problems, e.g. on "title: operating system")
    for r in [
        r'{{[Ss]hort description\|.+?}}',
        r'{{[Uu]se .+?\|.+?}}',
#         r'{{[Ii]nfobox .+?}}',
        r'<ref(?: name=\"(?:.|\n)*?\")?>(?:.|\n)*?</ref>',
        r"'''",
    ]:
        text = re.sub(r, '', text, flags=re.MULTILINE)
        text = text.lstrip('\n')
    return text

# %%
def get_early_links(text):
    [
        {
            'written': match.group(1),
            
        }
        for match in re.search(r'\[\[(.+?)\]\]', text)
    ]

# %%
clean_article(get_article('Cate Blanchett'))

# %%
get_article('computer program') 17

# %%
get_article('computer program').json()['query']['pages'][0]['revisions'][0]['slots']['main']['content']

# %%
p

# %%
clean_article(get_article('Q&A software'))

# %%
for match in re.finditer(r'\[\[(.*?)(?:\|(.*?))?\]\]', clean_article(get_article('computer programming'))):
    title, text = match.group(1), match.group(2)
    print('----')
    print(f'title: {title}')
    try:
        print(clean_article(get_article(title)))
    except:
        pass

# %%
https://en.wikipedia.org/wiki/Zero_History
https://en.wikipedia.org/wiki/Spook_Country
